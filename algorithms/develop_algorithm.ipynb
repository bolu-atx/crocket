# %%
import sys
sys.path.insert(1, '/home/b3arjuden/crocket')

from datetime import datetime
from decimal import Decimal
import itertools
from math import floor
from numpy import exp, linspace, median, mean, std
from pprint import pprint
from os import environ
from os.path import join
from scipy.stats import mannwhitneyu, ttest_ind, variation


import matplotlib.pyplot as plt
# %matplotlib inline

from crocket.sql.sql import Database
from crocket.utilities.credentials import get_credentials

# %%
# Environment variables

HOME_DIRECTORY_PATH = environ['HOME']
CREDENTIALS_FILE_PATH = join(HOME_DIRECTORY_PATH, '.credentials_unlocked.json')

HOSTNAME = 'localhost'
DATABASE_NAME = 'TEST3'

# %%
# Load SQL username and password
USERNAME, PASSCODE = get_credentials(CREDENTIALS_FILE_PATH)

# Create database connection
db = Database(hostname=HOSTNAME,
              username=USERNAME,
              password=PASSCODE,
              database_name=DATABASE_NAME)

# %%
tables = db.get_all_tables()

# %%
def run_algorithm2(data, status,
                  duration=1,
                  price_lag_time=30,
                  price_lag_duration=5,
                  price_lag_threshold=0.05,
                  volume_lag_duration=60,
                  buy_volume_lag_min=0,
                  buy_volume_lag_max=40,
                  sell_volume_lag_min=0,
                  sell_volume_lag_max=40,
                  stop_loss_percent=0.01,
                  stop_gain_increment=0.02,
                  max_hold_time=14400,
                  wait_time=14400,
                  digits=Decimal('1e-8')):

    time = data.get('datetime')
    buyvolume = data.get('buy_volume')
    sellvolume = data.get('sell_volume')
    wprice = data.get('wprice')

    current_time = time[-1]
    current_price = wprice[-1]
#     print(current_price)
#     if current_price == 0.00247892:
#         print(current_time, current_price)
#         input()
        
    last_buy_time_difference = (current_time - status.get('last_buy').get('start')).total_seconds()

    # Action if haven't bought coin
    if not status.get('bought'):

        # No action if purchased within time of last buy
        if last_buy_time_difference < wait_time:
            return status

        sample_buy_volume_mean = mean(buyvolume[-duration:])
        buy_volume_lag_total = sum(buyvolume[-(duration + volume_lag_duration):-duration])
        sell_volume_lag_total = sum(sellvolume[-(duration + volume_lag_duration):-duration])

        if sample_buy_volume_mean > 0 and \
            buy_volume_lag_min < buy_volume_lag_total < buy_volume_lag_max and \
                sell_volume_lag_min < sell_volume_lag_total < sell_volume_lag_max:
                    
            previous_price = Decimal(
                mean(wprice[-(duration + price_lag_time):-(duration + price_lag_time - price_lag_duration)])).quantize(digits)

            if sample_buy_volume_mean > 2 and \
                    abs((current_price - previous_price) / previous_price) < price_lag_threshold:
                # TODO: MAKE API CALL TO BUY (wrap in try)
                status['bought'] = True
                status['buy_lag'] = True
                status['current_buy'] = {'start': current_time,
                                         'buy_price': current_price,
                                         'buy_volume': sample_buy_volume_mean,
                                         'last30_buyvolume': sum(buyvolume[-(30+duration):-duration]),
                                         'last60_buyvolume': sum(buyvolume[-(60+duration):-duration]),
                                         'last30_sellvolume': sum(sellvolume[-(30+duration):-duration]),
                                         'last60_sellvolume': sum(sellvolume[-(60+duration):-duration])}

    # Action if have bought coin
    else:
        if 'buy_lag' in status and status.get('buy_lag'):
            status['current_buy']['lag_buy_price'] = current_price
            status['buy_lag'] = False
        
        current_buy = status.get('current_buy')
        current_buy_hold_time = (current_time - current_buy.get('start')).total_seconds()

        if status.get('current_stop_gain_percent') == 0.02:
            loss_threshold = 0
        else:
            loss_threshold = 0.01
            
        current_stop_gain_threshold = (current_buy.get('buy_price') * Decimal(status.get('current_stop_gain_percent') + 1)).quantize(digits)
        current_stop_gain_min_threshold = (current_buy.get('buy_price') * Decimal(status.get('current_stop_gain_percent') - loss_threshold + 1)).quantize(digits)
        
        next_stop_gain_threshold = (current_buy.get('buy_price') * Decimal(status.get('current_stop_gain_percent') + stop_gain_increment + 1)).quantize(digits)
        
        # Activate stop gain signal after passing threshold percentage
        if not status.get('stop_gain') and current_price > current_stop_gain_threshold:
            status['stop_gain'] = True
        elif status.get('stop_gain') and current_price > next_stop_gain_threshold:
            status['current_stop_gain_percent'] = status.get('current_stop_gain_percent') + stop_gain_increment

        # Sell if hit stop loss
        # Sell after hitting profit threshold followed by drop in price of X%
        # Sell after passing max hold time
        # Sell after detecting stop gain signal and price drop below stop gain price
        if (current_price < (current_buy.get('buy_price') * Decimal(1 - stop_loss_percent)).quantize(digits)) or \
                status.get('maximize_gain') or \
                current_buy_hold_time > max_hold_time or \
                (status.get('stop_gain') and current_price < current_stop_gain_min_threshold):
            # TODO: MAKE API CALL TO SELL (wrap in try)
            status['current_buy']['stop'] = current_time

            buy_price = current_buy.get('buy_price')

            status['current_buy']['sell_price'] = current_price
            status['current_buy']['profit'] = (((current_price - buy_price) / buy_price) * Decimal(0.995)).quantize(digits)

            status['bought'] = False
            status['stop_gain'] = False
            status['current_stop_gain_percent'] = 0.02
            status['maximize_gain'] = False

            status['last_buy'] = {'start': current_buy.get('start'),
                                  'buy_price': buy_price}

    return status

# %%
def benchmark():
    
    markets = db.get_all_tables()
    #markets = ['BTC-NEO']
    running_data = {}
    status = {}
    all_calls = {}
    
    bought_time = datetime(2017, 11, 11, 11, 11).astimezone(tz=None)

    last_buy = {'start': bought_time,
                'buy_price': 0}
    
    total_profit = 0
    total_lag_profit = 0
    
    for market in markets:
        status[market] = {'bought': False,
                          'last_buy': last_buy,
                          'current_buy': {},
                          'stop_gain': False,
                          'current_stop_gain_percent': 0.02}

        running_data[market] = {'datetime': [],
                        'wprice': [],
                        'buy_volume': [],
                        'sell_volume': []}
        
        all_calls[market] = []
        
    for market in markets:
        
        if market not in skip_list:
            data = db.select_query(market, '*')
            
            if data:
                time, price, wprice, volume, buyvolume, sellvolume, buyorder, sellorder = zip(*data)
                
                time = [x.astimezone(tz=None) for x in time]
                
                for ind in range(65, len(volume)):
                    running_data[market]['datetime'] = time[ind-65:ind]
                    running_data[market]['wprice'] = wprice[ind-65:ind]
                    running_data[market]['buy_volume'] = buyvolume[ind-65:ind]
                    running_data[market]['sell_volume'] = sellvolume[ind-65:ind]
                    
                    status[market] = run_algorithm2(running_data.get(market), status.get(market))
                    
                    completed_buy = status.get(market).get('current_buy')
                    
                    if completed_buy.get('profit') and completed_buy.get('lag_buy_price') > 0:
                        
                        completed_buy['lag_sell_price'] = wprice[ind]
                        completed_buy['lag_profit'] = (((completed_buy.get('lag_sell_price') - completed_buy.get('lag_buy_price')) / completed_buy.get('lag_buy_price')) * Decimal(0.995)).quantize(Decimal(10) ** -8)
                        
                        status[market]['current_buy'] = {}
                        all_calls[market].append(completed_buy)
                        
                        
                if all_calls.get(market):
                    profit = sum([x.get('profit') for x in all_calls.get(market) if 'profit' in x])
                    lag_profit = sum([x.get('lag_profit') for x in all_calls.get(market) if 'lag_profit' in x])
                    print('For {}, profit: {}, lag profit: {}'.format(market, str(profit), str(lag_profit)))
                    
                    total_profit += profit
                    total_lag_profit += lag_profit
    
    print('Total profit: {}'.format(total_profit))
    print('Total lag profit: {}'.format(total_lag_profit))
    
    return all_calls

# %%
skip_list = ['BTC-BCC', 'BTC-ETH', 'BTC-LSK', 'BTC-NEO', 'BTC-OMG', 'BTC-XRP', 'BTC-LTC']
#skip_list = []

calls = benchmark()
# Out:
# For BTC-1ST, profit: -0.02359432, lag profit: -0.04858278
# For BTC-ADX, profit: 0.00496979, lag profit: -0.00295950
# For BTC-AEON, profit: -0.02772082, lag profit: -0.04102962
# For BTC-AGRS, profit: -0.00140706, lag profit: -0.02154457
# For BTC-ANT, profit: -0.01121471, lag profit: -0.00583124
# For BTC-APX, profit: -0.02388926, lag profit: -0.02389809
# For BTC-ARK, profit: -0.95819827, lag profit: 0.03340021
# For BTC-BAT, profit: 0.00128347, lag profit: -0.00080303
# For BTC-BAY, profit: -0.05642712, lag profit: -0.00325180
# For BTC-BITB, profit: 0.05084512, lag profit: 0.02156024
# For BTC-BLK, profit: -0.01610497, lag profit: -0.01748146
# For BTC-BLOCK, profit: -0.03543808, lag profit: -0.03210342
# For BTC-BNT, profit: -0.96763132, lag profit: 0.03624343
# For BTC-BTG, profit: 0.02126344, lag profit: 0.06684747
# For BTC-BURST, profit: 0.06251144, lag profit: 0.03634742
# For BTC-CANN, profit: 0.16443953, lag profit: 0.12474719
# For BTC-CLUB, profit: 0.02163732, lag profit: 0.00088705
# For BTC-CVC, profit: 0.00053756, lag profit: 0.02036236
# For BTC-DASH, profit: -0.01988920, lag profit: -0.00649392
# For BTC-DCR, profit: -0.05092777, lag profit: 0.08112477
# For BTC-DCT, profit: -0.00569545, lag profit: -0.04066700
# For BTC-DGB, profit: -0.03775118, lag profit: -0.04582763
# For BTC-DMD, profit: 0.01875365, lag profit: -0.03322157
# For BTC-DNT, profit: 0.08047963, lag profit: 0.10944091
# For BTC-DOGE, profit: -0.08993819, lag profit: 0.08435150
# For BTC-DOPE, profit: 0.02068781, lag profit: 0.04019201
# For BTC-EDG, profit: 0.00846367, lag profit: -0.03050462
# For BTC-EMC, profit: -0.01832704, lag profit: 0.02452149
# For BTC-EMC2, profit: 0.03786011, lag profit: 0.04003618
# For BTC-ENG, profit: -0.04870921, lag profit: -0.03792991
# For BTC-ETC, profit: 0.03084623, lag profit: 0.03458865
# For BTC-EXP, profit: 0.00579327, lag profit: -0.00625649
# For BTC-FCT, profit: -0.05972519, lag profit: -0.04506049
# For BTC-FLO, profit: -0.03787238, lag profit: -0.01918319
# For BTC-FUN, profit: 0.16565450, lag profit: 0.15084826
# For BTC-GAME, profit: -0.02883604, lag profit: -0.05130079
# For BTC-GBYTE, profit: -0.02572862, lag profit: -0.02961725
# For BTC-GEO, profit: -0.01345344, lag profit: -0.01611981
# For BTC-GLD, profit: 0.08674359, lag profit: 0.08572308
# For BTC-GNO, profit: -0.01146056, lag profit: -0.01371835
# For BTC-GNT, profit: 0.09709940, lag profit: 0.05736378
# For BTC-GRC, profit: 0.01194000, lag profit: 0.02074975
# For BTC-GRS, profit: -0.00346175, lag profit: 0.03917993
# For BTC-GUP, profit: -0.04404022, lag profit: 0.01108256
# For BTC-INCNT, profit: 0.27042164, lag profit: 0.19643881
# For BTC-ION, profit: -0.01776344, lag profit: -0.01776344
# For BTC-IOP, profit: -0.06180596, lag profit: -0.07569947
# For BTC-KMD, profit: 0.00947315, lag profit: -0.04132945
# For BTC-LMC, profit: 0.02597390, lag profit: 0.00296720
# For BTC-MAID, profit: 0.04742319, lag profit: 0.02014061
# For BTC-MANA, profit: 0.02363992, lag profit: 0.01569001
# For BTC-MCO, profit: -0.98779050, lag profit: -0.96575641
# For BTC-MER, profit: -0.07002592, lag profit: -0.01377409
# For BTC-MONA, profit: -0.01055656, lag profit: -0.00767515
# For BTC-MTL, profit: -0.01642762, lag profit: 0.00373702
# For BTC-MUSIC, profit: 0.01631148, lag profit: 0.01355586
# For BTC-MYST, profit: -0.00047863, lag profit: -0.03429579
# For BTC-NAV, profit: -0.03013130, lag profit: -0.03764911
# For BTC-NBT, profit: 0.03369153, lag profit: 0.02547075
# For BTC-NEOS, profit: 0.01108764, lag profit: 0.00929248
# For BTC-NLG, profit: 0.02631304, lag profit: -0.01237123
# For BTC-NMR, profit: -0.02050769, lag profit: -0.02503303
# For BTC-NXC, profit: -0.02867042, lag profit: -0.04071680
# For BTC-NXT, profit: -0.01214143, lag profit: -0.01486850
# For BTC-OK, profit: -0.04627166, lag profit: -0.02838741
# For BTC-OMNI, profit: 0.01833424, lag profit: 0.02882089
# For BTC-PART, profit: -0.02749723, lag profit: 0.00280939
# For BTC-PAY, profit: -0.01966771, lag profit: -0.01405736
# For BTC-PIVX, profit: -0.05374646, lag profit: -0.03891927
# For BTC-POT, profit: 0.04978642, lag profit: 0.06315222
# For BTC-POWR, profit: -0.12673772, lag profit: -0.10915819
# For BTC-QRL, profit: 0.04923647, lag profit: 0.03304495
# For BTC-QTUM, profit: 0.05732135, lag profit: 0.04062584
# For BTC-RCN, profit: 0.09005932, lag profit: 0.05661807
# For BTC-RDD, profit: 0.11825090, lag profit: 0.19955030
# For BTC-REP, profit: -0.05199044, lag profit: -0.02136967
# For BTC-RISE, profit: -0.00736042, lag profit: -0.00592239
# For BTC-RLC, profit: -0.03035006, lag profit: -0.00509049
# For BTC-SALT, profit: -0.11155630, lag profit: -0.09298632
# For BTC-SHIFT, profit: 0.02614363, lag profit: -0.00494432
# For BTC-SLR, profit: 0.01338727, lag profit: 0.02589750
# For BTC-SLS, profit: -0.05857839, lag profit: -0.07099314
# For BTC-SNT, profit: -0.05351490, lag profit: -0.03813928
# For BTC-SPR, profit: -0.01153568, lag profit: -0.02235213
# For BTC-STEEM, profit: -0.03647019, lag profit: -0.05744850
# For BTC-STRAT, profit: -0.02985479, lag profit: -0.03132445
# For BTC-SYS, profit: -0.04156420, lag profit: -0.06910212
# For BTC-THC, profit: -0.03728596, lag profit: -0.03882576
# For BTC-TKS, profit: 0.09362576, lag profit: 0.04814739
# For BTC-TRIG, profit: 0.02984803, lag profit: 0.00872109
# For BTC-TRST, profit: -0.03067184, lag profit: 0.01786323
# For BTC-UBQ, profit: -0.09113909, lag profit: -0.08911212
# For BTC-UNB, profit: 0.01401054, lag profit: -0.11852268
# For BTC-VIA, profit: -0.02250453, lag profit: -0.03527705
# For BTC-VIB, profit: 0.06802917, lag profit: -0.01146080
# For BTC-VOX, profit: 0.00773271, lag profit: -0.03031622
# For BTC-VRC, profit: -0.02584912, lag profit: 0.01438050
# For BTC-VTC, profit: 0.06651680, lag profit: 0.03655359
# For BTC-WAVES, profit: -0.01110085, lag profit: 0.01869561
# For BTC-WINGS, profit: -0.03266397, lag profit: -0.02240897
# For BTC-XCP, profit: -0.04077552, lag profit: -0.05383976
# For BTC-XDN, profit: -0.04657046, lag profit: -0.06480078
# For BTC-XEL, profit: -0.05749091, lag profit: -0.05328361
# For BTC-XLM, profit: 0.01935170, lag profit: 0.01894854
# For BTC-XVC, profit: 0.01281417, lag profit: 0.02702988
# For BTC-XZC, profit: 0.01495851, lag profit: -0.00179081
# For BTC-ZEC, profit: -0.05125086, lag profit: -0.04360205
# For BTC-ZEN, profit: -0.02971681, lag profit: 0.04095250
# Total profit: -2.95190570
# Total lag profit: -0.94505218

# %%
total_profit = []
all_calls = []

for k in calls.keys():
    
    for x in calls.get(k):
        
        if x.get('last60_buyvolume') > 10 and x.get('last60_buyvolume') < 40 and \
        x.get('last60_sellvolume') > 10 and x.get('last60_sellvolume') < 40:
            x['market'] = k
            total_profit.append(x.get('lag_profit'))
            all_calls.append(x)
        
print('Total lag profit: {}'.format(str(sum(total_profit))))
print('Number of calls: {}'.format(str(len(total_profit))))
# Out:
# Total lag profit: 0.37738378
# Number of calls: 182

# %%
start = []
stop = []

for c in sorted_calls:
    
    start.append(int((c[2] - sorted_calls[0][2]).total_seconds()))
    stop.append(int((c[3] - sorted_calls[0][2]).total_seconds()))

# %%
sorted_calls = sorted([(x.get('market'), x.get('buy_price'), x.get('sell_price'), x.get('profit'), x.get('start'), x.get('stop')) for x in all_calls], key=lambda x:x[4])

# %%
sorted_calls
# Out:
# [('BTC-DASH',
#   Decimal('0.04899006'),
#   Decimal('0.04834229'),
#   Decimal('-0.01315637'),
#   datetime.datetime(2017, 12, 9, 19, 10, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 9, 19, 19, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-NEO',
#   Decimal('0.00247892'),
#   Decimal('0.00245000'),
#   Decimal('-0.01160804'),
#   datetime.datetime(2017, 12, 9, 20, 4, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 9, 20, 7, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-SALT',
#   Decimal('0.00054483'),
#   Decimal('0.00053236'),
#   Decimal('-0.02277343'),
#   datetime.datetime(2017, 12, 9, 20, 5, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 9, 20, 6, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-XMR',
#   Decimal('0.01689929'),
#   Decimal('0.01669032'),
#   Decimal('-0.01230378'),
#   datetime.datetime(2017, 12, 9, 20, 8, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 9, 20, 10, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-VTC',
#   Decimal('0.00050429'),
#   Decimal('0.00051423'),
#   Decimal('0.01961233'),
#   datetime.datetime(2017, 12, 9, 20, 14, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 9, 20, 31, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-MCO',
#   Decimal('0.00076278'),
#   Decimal('0.00074028'),
#   Decimal('-0.02934988'),
#   datetime.datetime(2017, 12, 9, 20, 15, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 9, 20, 24, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-TIX',
#   Decimal('0.00005888'),
#   Decimal('0.00005823'),
#   Decimal('-0.01098421'),
#   datetime.datetime(2017, 12, 9, 20, 18, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 9, 20, 20, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-QTUM',
#   Decimal('0.00082786'),
#   Decimal('0.00081947'),
#   Decimal('-0.01008389'),
#   datetime.datetime(2017, 12, 9, 20, 28, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 9, 20, 39, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-BTG',
#   Decimal('0.01510591'),
#   Decimal('0.01536228'),
#   Decimal('0.01688665'),
#   datetime.datetime(2017, 12, 9, 20, 46, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 9, 20, 56, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-OMG',
#   Decimal('0.00059376'),
#   Decimal('0.00058654'),
#   Decimal('-0.01209900'),
#   datetime.datetime(2017, 12, 9, 20, 51, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 9, 20, 59, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-MANA',
#   Decimal('0.00000510'),
#   Decimal('0.00000531'),
#   Decimal('0.04097059'),
#   datetime.datetime(2017, 12, 9, 21, 26, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 9, 21, 30, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-ADA',
#   Decimal('0.00000778'),
#   Decimal('0.00000787'),
#   Decimal('0.01151028'),
#   datetime.datetime(2017, 12, 9, 21, 51, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 9, 22, 1, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-XLM',
#   Decimal('0.00000847'),
#   Decimal('0.00000837'),
#   Decimal('-0.01174734'),
#   datetime.datetime(2017, 12, 9, 21, 54, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 9, 22, 19, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-ETC',
#   Decimal('0.00184074'),
#   Decimal('0.00181161'),
#   Decimal('-0.01574603'),
#   datetime.datetime(2017, 12, 9, 22, 4, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 9, 22, 39, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-XRP',
#   Decimal('0.00001682'),
#   Decimal('0.00001663'),
#   Decimal('-0.01123960'),
#   datetime.datetime(2017, 12, 9, 22, 5, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 9, 22, 38, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-STRAT',
#   Decimal('0.00055087'),
#   Decimal('0.00054523'),
#   Decimal('-0.01018716'),
#   datetime.datetime(2017, 12, 9, 22, 33, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 9, 22, 53, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-LTC',
#   Decimal('0.00998997'),
#   Decimal('0.00987116'),
#   Decimal('-0.01183346'),
#   datetime.datetime(2017, 12, 9, 23, 7, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 9, 23, 24, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-DASH',
#   Decimal('0.04975231'),
#   Decimal('0.04920042'),
#   Decimal('-0.01103729'),
#   datetime.datetime(2017, 12, 9, 23, 30, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 9, 23, 35, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-NEO',
#   Decimal('0.00249977'),
#   Decimal('0.00247035'),
#   Decimal('-0.01171024'),
#   datetime.datetime(2017, 12, 10, 0, 53, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 10, 1, 37, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-POWR',
#   Decimal('0.00003860'),
#   Decimal('0.00004050'),
#   Decimal('0.04897668'),
#   datetime.datetime(2017, 12, 10, 1, 7, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 10, 1, 21, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-XEM',
#   Decimal('0.00002590'),
#   Decimal('0.00002640'),
#   Decimal('0.01920849'),
#   datetime.datetime(2017, 12, 10, 1, 7, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 10, 1, 45, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-EMC2',
#   Decimal('0.00012213'),
#   Decimal('0.00012409'),
#   Decimal('0.01596823'),
#   datetime.datetime(2017, 12, 10, 1, 15, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 10, 1, 26, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-MANA',
#   Decimal('0.00000579'),
#   Decimal('0.00000587'),
#   Decimal('0.01374784'),
#   datetime.datetime(2017, 12, 10, 1, 30, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 10, 1, 50, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-BCC',
#   Decimal('0.09323341'),
#   Decimal('0.09226371'),
#   Decimal('-0.01034877'),
#   datetime.datetime(2017, 12, 10, 1, 45, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 10, 2, 40, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-XLM',
#   Decimal('0.00000834'),
#   Decimal('0.00000848'),
#   Decimal('0.01670264'),
#   datetime.datetime(2017, 12, 10, 1, 59, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 10, 2, 53, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-LSK',
#   Decimal('0.00059909'),
#   Decimal('0.00059254'),
#   Decimal('-0.01087858'),
#   datetime.datetime(2017, 12, 10, 2, 26, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 10, 2, 31, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-ADA',
#   Decimal('0.00000765'),
#   Decimal('0.00000779'),
#   Decimal('0.01820915'),
#   datetime.datetime(2017, 12, 10, 2, 36, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 10, 5, 26, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-VTC',
#   Decimal('0.00056124'),
#   Decimal('0.00055488'),
#   Decimal('-0.01127539'),
#   datetime.datetime(2017, 12, 10, 2, 47, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 10, 2, 50, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-THC',
#   Decimal('0.00000850'),
#   Decimal('0.00000862'),
#   Decimal('0.01404706'),
#   datetime.datetime(2017, 12, 10, 3, 8, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 10, 3, 19, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-LTC',
#   Decimal('0.00974800'),
#   Decimal('0.00957287'),
#   Decimal('-0.01787591'),
#   datetime.datetime(2017, 12, 10, 3, 14, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 10, 3, 17, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-ETC',
#   Decimal('0.00187339'),
#   Decimal('0.00185314'),
#   Decimal('-0.01075524'),
#   datetime.datetime(2017, 12, 10, 3, 25, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 10, 4, 57, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-WAVES',
#   Decimal('0.00061314'),
#   Decimal('0.00063973'),
#   Decimal('0.04315010'),
#   datetime.datetime(2017, 12, 10, 4, 39, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 10, 5, 15, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-XEM',
#   Decimal('0.00002639'),
#   Decimal('0.00002668'),
#   Decimal('0.01093407'),
#   datetime.datetime(2017, 12, 10, 5, 11, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 10, 5, 22, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-BTG',
#   Decimal('0.01560866'),
#   Decimal('0.01578926'),
#   Decimal('0.01151265'),
#   datetime.datetime(2017, 12, 10, 5, 23, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 10, 5, 59, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-NEO',
#   Decimal('0.00239979'),
#   Decimal('0.00236376'),
#   Decimal('-0.01493874'),
#   datetime.datetime(2017, 12, 10, 5, 27, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 10, 5, 31, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-POWR',
#   Decimal('0.00003836'),
#   Decimal('0.00003793'),
#   Decimal('-0.01115355'),
#   datetime.datetime(2017, 12, 10, 5, 29, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 10, 5, 31, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-STRAT',
#   Decimal('0.00060614'),
#   Decimal('0.00059972'),
#   Decimal('-0.01053865'),
#   datetime.datetime(2017, 12, 10, 5, 32, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 10, 5, 33, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-DASH',
#   Decimal('0.04710065'),
#   Decimal('0.04661613'),
#   Decimal('-0.01023547'),
#   datetime.datetime(2017, 12, 10, 5, 36, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 10, 5, 48, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-XRP',
#   Decimal('0.00001602'),
#   Decimal('0.00001585'),
#   Decimal('-0.01055868'),
#   datetime.datetime(2017, 12, 10, 5, 42, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 10, 6, 3, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-QTUM',
#   Decimal('0.00077312'),
#   Decimal('0.00076362'),
#   Decimal('-0.01222643'),
#   datetime.datetime(2017, 12, 10, 6, 7, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 10, 6, 17, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-XMR',
#   Decimal('0.01601682'),
#   Decimal('0.01624663'),
#   Decimal('0.01427630'),
#   datetime.datetime(2017, 12, 10, 6, 26, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 10, 6, 51, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-SALT',
#   Decimal('0.00048588'),
#   Decimal('0.00050591'),
#   Decimal('0.04101805'),
#   datetime.datetime(2017, 12, 10, 6, 33, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 10, 7, 3, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-LSK',
#   Decimal('0.00051866'),
#   Decimal('0.00051109'),
#   Decimal('-0.01452233'),
#   datetime.datetime(2017, 12, 10, 6, 37, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 10, 7, 41, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-MCO',
#   Decimal('0.00079745'),
#   Decimal('0.00078544'),
#   Decimal('-0.01498520'),
#   datetime.datetime(2017, 12, 10, 6, 45, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 10, 6, 50, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-VTC',
#   Decimal('0.00050604'),
#   Decimal('0.00049986'),
#   Decimal('-0.01215141'),
#   datetime.datetime(2017, 12, 10, 7, 35, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 10, 7, 37, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST'))),
#  ('BTC-OMG',
#   Decimal('0.00052195'),
#   Decimal('0.00051647'),
#   Decimal('-0.01044659'),
#   datetime.datetime(2017, 12, 10, 7, 46, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')),
#   datetime.datetime(2017, 12, 10, 7, 50, 40, tzinfo=datetime.timezone(datetime.timedelta(-1, 57600), 'PST')))]

# %%
field = 'last60_sellvolume'
x1 = [float(x.get(field)) for x in pos_calls]
x2 = [float(x.get(field)) for x in neg_calls]

bins = linspace(0, 150, 100)

plt.hist(x1, bins, alpha=0.6, color='b', label='POS')
plt.hist(x2, bins, alpha=0.3, color='r', label='NEG')
plt.show()

# %%
list(itertools.chain.from_iterable([[calls.get(k)] for k in calls]))

# %%
for k in sorted(calls.keys()):
    
    if calls.get(k):
        print('{}: total profit: {}, loss: {}, calls: {}, calls @ profit threshold: {}'.format(
            k, str(sum([x.get('profit') for x in calls[k] if 'profit' in x])), str(sum([x.get('profit') for x in calls[k] if 'profit' in x and x.get('profit') < 0])), 
            len(calls[k]), str(len([x for x in calls[k] if 'profit' in x and x.get('profit') > 0.05]))))

# %%
mv = {'loss': [],
      'gain': []}

tv = {'loss': [],
      'gain': []}

tp = [0 for x in range(50)]

for k in sorted(calls.keys()):
    
    for e in calls.get(k):
        
        if e.get('profit') <= 0.02:
            mv['loss'].append(float(e.get('buy_volume')))
            tv['loss'].append(float(e.get('buy_volume_total')))
        else:
            mv['gain'].append(float(e.get('buy_volume')))
            tv['gain'].append(float(e.get('buy_volume_total')))
            
        tmp = floor(float(e.get('buy_volume_total')))

        tp[tmp] += float(e.get('profit'))
            
        print('{}: profit: {}, mean_volume: {}, total_volume: {}'.format(
            k, str(e.get('profit')), str(e.get('buy_volume')), str(e.get('buy_volume_total'))))

# %%
calls.get('BTC-TIX')

# %%
for ii in range(17, 29):

    orders = list(itertools.chain.from_iterable([[x for x in calls.get(y) if 0 < (x.get('time')-datetime(2017, 11, ii, 20, 14)).total_seconds() < 86400] 
                  for y in calls]))
    
    print('11/{}: {} orders, profit: {}'.format(str(ii), str(len(orders)), str(sum([x.get('profit') for x in orders if x.get('profit')]))))
    
    #pprint(sorted([(x.get('time'), x.get('profit')) for x in orders]))

# %%
for x in sorted(calls.keys()):
    
    pprint((x, calls.get(x)))

# %%
data = db.select_query('BTC-BAY', '*')

time, price, wprice, volume, buyvolume, sellvolume, buyorder, sellorder = zip(*data)

calls = call(time, wprice, buyvolume, buyorder,
                             duration=params.get('duration'),
                             price_lag_time=params.get('price_lag_time'),
                             price_lag_duration=params.get('price_lag_duration'),
                             price_lag_threshold=params.get('price_lag_threshold'),
                             volume_lag_duration=params.get('volume_lag_duration'),
                             volume_lag_threshold=params.get('volume_lag_threshold'),
                             profit_percent=params.get('profit_percent'),
                             stop_loss_percent=params.get('stop_loss_percent'),
                             stop_gain_percent=params.get('stop_gain_percent'),
                             max_hold_time=params.get('max_hold_time'),
                             wait_time=params.get('wait_time'))

# %%
calls

# %%
for table in tables:
    
    data = db.select_query(table, '*')

    time, price, wprice, volume, buyvolume, sellvolume, buyorder, sellorder = zip(*data)
    
    ind = [i for i in range(duration, len(buyvolume)) if mean(buyvolume[i-duration:i]) > 2 
           and variation(buyvolume[i-duration:i]) < 1
           and all([1 if x > 1 else 0 for x in buyvolume[i-duration:i]])]
    
    if ind:
        print('Found {} hits for {}: {}'.format(str(len(ind)), table, ','.join(map(str, ind))))
        plt.plot(range(len(time)), wprice, markevery=ind, marker='o', markerfacecolor='r', markersize=10)
        plt.show()
        plt.plot(range(len(time)), buyvolume, markevery=ind, marker='o', markerfacecolor='r', markersize=10)
        plt.show()
        for i in ind:
            print(i, buyvolume[i-duration:i])
            print(i, time[i])
        input('NEXT')
    else:
        print('No hits found for {}'.format(table))
